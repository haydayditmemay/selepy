# %%
from selenium import webdriver
import time
import random
from openpyxl import Workbook, load_workbook
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import sys

# %%
def vao():
    path = Service(r"C:\Users\Administrator\Downloads\69696996\chromedriver.exe")
    cho = webdriver.ChromeOptions()
    cho.add_experimental_option("detach",True)
    dr = webdriver.Chrome(service=path,options=cho)
    dr.get('https://congdanhoctap.vn/dang-nhap')
    dr.maximize_window()
    return dr

# %%
def doc():
    wb = load_workbook('')
    ws = wb['']
    co = ws['']
    return(co,wb,ws)

# %%
def data_kt():
    # trả lời câu 3 phase 1
    data_div31 = ['//*[@id="surveyForm-p-0"]/table/tbody/tr[3]/td[3]/div/div[3]/div[2]/div',
                '//*[@id="surveyForm-p-0"]/table/tbody/tr[3]/td[3]/div/div[4]/div[2]/div',
                '//*[@id="surveyForm-p-0"]/table/tbody/tr[3]/td[3]/div/div[4]/div[1]/div']
    
    # trả lời câu 4 phase 1
    data_div41 = ['//*[@id="surveyForm-p-0"]/table/tbody/tr[4]/td[3]/div/div[3]/div[2]/div',
                '//*[@id="surveyForm-p-0"]/table/tbody/tr[4]/td[3]/div/div[4]/div[2]/div',
                '//*[@id="surveyForm-p-0"]/table/tbody/tr[4]/td[3]/div/div[4]/div[1]/div']
    
    # trả lời câu 3 phase 2
    data_div32 = ['//*[@id="surveyForm-p-1"]/table/tbody/tr[3]/td[3]/div/div[3]/div[2]/div',
                '//*[@id="surveyForm-p-1"]/table/tbody/tr[3]/td[3]/div/div[4]/div[2]/div',
                '//*[@id="surveyForm-p-1"]/table/tbody/tr[3]/td[3]/div/div[4]/div[1]/div']
    
    # trả lời câu 4 phase 2
    data_div42 = ['//*[@id="surveyForm-p-1"]/table/tbody/tr[4]/td[3]/div/div[3]/div[2]/div',
                '//*[@id="surveyForm-p-1"]/table/tbody/tr[4]/td[3]/div/div[4]/div[2]/div',
                '//*[@id="surveyForm-p-1"]/table/tbody/tr[4]/td[3]/div/div[4]/div[1]/div']
    
        
    return(data_div31,data_div32,data_div41,data_div42)

def lam_kt():
    #vao chrome
    a = vao()
    wait = WebDriverWait(a,10)
    
    #đọc excel
    co = doc()

    #data
    data_div31,data_div32,data_div41,data_div42 = data_kt()

    for i in range(len(co)):

    # đăng nhập 
        #Điền cccd
        dk = wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="username"]'
            )))
        dk.send_keys(f'{co[i].value}')
        #Điền mk
        wait.until(EC.element_to_be_clickable((
        By.XPATH, '//*[@id="password"]'
        ))).send_keys('123456')

        #bấm đăng nhập 
        dang_nhap_button = a.find_elements(
            By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[3]/div/button'
            )
        dang_nhap_button1  = a.find_elements(
            By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[4]/div/button'
            )
        if dang_nhap_button:
            wait.until(EC.element_to_be_clickable((
                By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[3]/div/button'
                ))).click()
        elif dang_nhap_button1:
            wait.until(EC.element_to_be_clickable((
                By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[4]/div/button'
                ))).click()  
            
        #Bấm vào làm bài kt 
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '/html/body/div/div[3]/div[2]/div/div/div[1]/div[3]/div[2]/div[1]/a/p[1]'
            ))).click() 

        # trả lời câu 1 phase 1
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm-p-0"]/table/tbody/tr[1]/td[3]/div/div[3]/div[2]/div'
            ))).click()
        # trả lời câu 2 phase 1
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm-p-0"]/table/tbody/tr[2]/td[3]/div/div[3]/div[2]/div'
            ))).click()
        # trả lời câu 3 phase 1
        op31 = random.choice(data_div31)
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '{}'.format(op31)
            ))).click()
        # trả lời câu 4 phase 1
        op41 = random.choice(data_div41)
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '{}'.format(op41)
            ))).click()
        #bấm tiếp
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm"]/div[3]/ul/li[2]/a'
            ))).click()
        
        # trả lời câu 1 phase 2
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm-p-1"]/table/tbody/tr[1]/td[3]/div/div[3]/div[2]/div'
            ))).click()
        # trả lời câu 2 phase 2
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm-p-1"]/table/tbody/tr[2]/td[3]/div/div[2]/div[2]/div'
            ))).click()
        # trả lời câu 3 phase 2
        op32 = random.choice(data_div32)
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '{}'.format(op32)
            ))).click()
        # trả lời câu 4 phase 2
        op42 = random.choice(data_div42)
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '{}'.format(op42)
            ))).click()
        #bấm tiếp
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm"]/div[3]/ul/li[2]/a'
            ))).click()

        # trả lời câu 1 phase 3
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm-p-2"]/table/tbody/tr[1]/td[3]/div/div[4]/div[2]/div'
            ))).click()
        # trả lời câu 2 phase 3
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm-p-2"]/table/tbody/tr[2]/td[3]/div/div[4]/div[2]/div'
            ))).click()
        #bấm gửi thông tin
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="surveyForm"]/div[3]/ul/li[3]/a'
            ))).click()
        
        #bấm đăng xuất
        wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="bs-example-navbar-collapse-1"]/ul[2]/li[2]/a'
            ))).click()

# %%
def thd_ma():
    #vao chrome
    a = vao()
    wait = WebDriverWait(a,10)
    achains = ActionChains(a)

    #vào đọc excel
    co,wb =doc()

    # lưu cccd bị lỗi
    data = []
    
    # đăng nhập 
    for rep in range(0,len(co)):
        #Điền cccd
        val = co[rep].value
        dk = wait.until(EC.element_to_be_clickable((
            By.XPATH, '//*[@id="username"]'
            )))
        dk.send_keys('{}'.format(val))
        #Điền mk
        wait.until(EC.element_to_be_clickable((
        By.XPATH, '//*[@id="password"]'
        ))).send_keys('123456')

        #bấm đăng nhập
        dang_nhap_button = a.find_elements(
            By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[3]/div/button'
            )
        dang_nhap_button1  = a.find_elements(
            By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[4]/div/button'
            )
        if dang_nhap_button :
            wait.until(EC.element_to_be_clickable((
                By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[3]/div/button'
                ))).click()
        elif dang_nhap_button1 :
            wait.until(EC.element_to_be_clickable((
                By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[4]/div/button'
                ))).click()
                 
        #-------kiểm tra coi tk có đk nếu không đúng thì ghi vào sheet exccel ms, đúng thì làm tiếp----------
        #tìm element error 
        er_ele = a.find_elements(By.XPATH, '/html/body/div/div[3]/div[2]/form/div/div/div/div[1]')

        if er_ele:

            for i in er_ele:
                er_ele_text = i.text

            if "Tài khoản hoặc mật khẩu không đúng" in er_ele_text:
                
                dk = wait.until(EC.element_to_be_clickable((
                        By.XPATH, '//*[@id="username"]'
                        )))
                achains.move_to_element(dk).click().click().perform()
                data.append(val)
                    
        else:
            #bấm vào sửa tt
            ele = wait.until(EC.element_to_be_clickable((
                By.XPATH, '/html/body/div/div[3]/div[2]/div/div/div[1]/div[1]/a[1]'
                )))
            #Thay Mã    
            ma = entry.get()
            ele = wait.until(EC.element_to_be_clickable((
                By.XPATH, '//*[@id="unitcode"]'
                ))) 
            achains.move_to_element(ele).click().click().click().send_keys('{}'.format(ma)).perform()
            #Lưu tt
            wait.until(EC.element_to_be_clickable((
                By.XPATH, '/html/body/div/div[3]/div[2]/div[1]/form/div[5]/button'
                ))).click()  
            #Đăng xuất
            wait.until(EC.element_to_be_clickable((
                By.XPATH, '//*[@id="bs-example-navbar-collapse-1"]/ul[2]/li[2]/a'
                ))).click()
            
    # tạo sheet excel mới để ghi các tk bị lỗi
    new_sheet =  wb.create_sheet(title='Sheet_dkbl')
    wb.save(filename=excel_path)
    sheet_dkbl = wb['Sheet_dkbl']

    for re in data:
        sheet_dkbl.append([re])

    wb.save(filename=excel_path)

    return(new_sheet)
